# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../datasets/one_hot_encoded/combined-data.csv").query("Country_Uganda == 1")
# Extract the relevant columns, Temperature and Co2

relevant_data = data[['Temperature', 'Co2']]

correlation_matrix = relevant_data.corr()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 10}, center=0)
plt.title('Correlation Matrix')
plt.show()

# %%
data = pd.read_csv("../datasets/clean/combined-data.csv")

# Remove the country column
data = data.drop(columns=['Country'])

data.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 4
#       1 data = pd.read_csv("../datasets/clean/combined-data.csv")
# ----> 4 data.corr()
#
# File ~/Epic_3/.venv/lib/python3.11/site-packages/pandas/core/frame.py:11036, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11034 cols = data.columns
#   11035 idx = cols.copy()
# > 11036 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11038 if method == "pearson":
#   11039     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/Epic_3/.venv/lib/python3.11/site-packages/pandas/core/frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# -> 1981 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1982 if result.dtype is not dtype:
# ...
